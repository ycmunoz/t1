# %%
#importacion de librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.datasets import  fashion_mnist
# Out:
# 2023-07-24 05:45:06.376042: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import cv2
import numpy as np
from tensorflow.keras.datasets import fashion_mnist

# Cargando el dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
#aplicando el desenfocado medio
def add_noise(X):
    res = []
    for pic in X:
        blur = cv2.medianblur((pic*255).astype(np.uint8), 5
        blur = np.clip(blur, 0, 1)
        res.append(blur)
    return np.array(res)
noise_train = add_noise(X_train)
noise_test = add_noise(X_test)

# %%
#contruyendo el modelo
from keras import models, layers
model = models.Sequential()
#encode
model.add(layers.Conv2D(64, (2, 2), strides = 1, padding = 'same', input_shape = (28, 28, 1)))
model.add(layers.Conv2D(32, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2D(16, (2, 2), strides = 1, padding = 'same'))
#latent
model.add(layers.Conv2D(8, (2, 2), strides = 1, padding = 'same'))
#decode
model.add(layers.Conv2DTranspose(16, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(32, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(64, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(1, (1, 1), strides = 1, activation = 'sigmoid', padding = 'same'))
# Out:
# 2023-07-22 20:21:56.860239: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-22 20:21:56.884247: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
#entrenando el modelo
model.compile(loss = 'mse', optimizer = 'adam')
model.fit(noise_train.reshape(-1, 28, 28, 1), 
          X_train.reshape(-1, 28, 28, 1), 
          epochs = 100, 
          batch_size = 2000, 
          validation_data = (noise_test.reshape(-1  , 28, 28, 1),X_test.reshape(-1, 28, 28, 1)))

model.save("model-d_medio.h5")
# Out:
# Epoch 1/100
# 30/30 [==============================] - 135s 4s/step - loss: 0.0803 - val_loss: 0.0453
# Epoch 2/100
# 30/30 [==============================] - 122s 4s/step - loss: 0.0426 - val_loss: 0.0410
# Epoch 3/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0406 - val_loss: 0.0403
# Epoch 4/100
# 30/30 [==============================] - 105s 3s/step - loss: 0.0395 - val_loss: 0.0389
# Epoch 5/100
# 30/30 [==============================] - 107s 4s/step - loss: 0.0390 - val_loss: 0.0384
# Epoch 6/100
# 30/30 [==============================] - 106s 4s/step - loss: 0.0384 - val_loss: 0.0387
# Epoch 7/100
# 30/30 [==============================] - 107s 4s/step - loss: 0.0390 - val_loss: 0.0379
# Epoch 8/100
# 30/30 [==============================] - 167s 6s/step - loss: 0.0380 - val_loss: 0.0376
# Epoch 9/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0379 - val_loss: 0.0374
# Epoch 10/100
# 30/30 [==============================] - 100s 3s/step - loss: 0.0380 - val_loss: 0.0383
# Epoch 11/100
# 30/30 [==============================] - 100s 3s/step - loss: 0.0379 - val_loss: 0.0380
# Epoch 12/100
# 30/30 [==============================] - 101s 3s/step - loss: 0.0377 - val_loss: 0.0373
# Epoch 13/100
# 30/30 [==============================] - 101s 3s/step - loss: 0.
100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0371 - val_loss: 0.0368
# Epoch 90/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0370 - val_loss: 0.0370
# Epoch 91/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0371 - val_loss: 0.0369
# Epoch 92/100
# 30/30 [==============================] - 101s 3s/step - loss: 0.0370 - val_loss: 0.0369
# Epoch 93/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0367
# Epoch 94/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0370 - val_loss: 0.0368
# Epoch 95/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0371 - val_loss: 0.0368
# Epoch 96/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0368
# Epoch 97/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0368
# Epoch 98/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0368
# Epoch 99/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0370
# Epoch 100/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0370 - val_loss: 0.0370

# %%
#cargando el modelo
model = keras.models.load_model('model-d_medio.h5')

#viendo la arquitectura del modelo
model.summary()
# Out:
# 2023-07-24 05:50:11.033779: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 05:50:11.035147: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        8224
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 16)        2064
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 8)         520
#
#  conv2d_transpose (Conv2DTra  (None, 28, 28, 16)       528
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       2080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 64)       8256
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        65
#  ranspose)
#
# =================================================================
# Total params: 22,057
# Trainable params: 22,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
import random
#utility function to pick samples to be tested
def get_samples(arr, n):
    temp = random.sample(range(len(arr)), n)
    result = arr[temp]
    return result, temp
num = 15
org, temp = get_samples(X_test, num)
blur = noise_test[temp]
preds = model.predict(blur.reshape(-1, 28, 28, 1))
preds = preds.reshape(-1, 28, 28)
#plotting results
plt.figure(figsize = (15, 15))
print('Original Images')
for i in range(num):
    plt.subplot(1, num, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(org[i], cmap=plt.cm.binary)
plt.show()
plt.figure(figsize = (15, 15))
print('Blurred Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(blur[i], cmap=plt.cm.binary)
plt.show()
plt.figure(figsize = (15, 15))
print('Predicted Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(preds[i], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 229ms/step
# Original Images
# Blurred Images
# Predicted Images

# %%
#1era imagen  original
plt.figure(figsize=(2,2))
plt.imshow(org[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
#1era imagen desfocada
plt.figure(figsize=(2,2))
plt.imshow(blur[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
#1era imagen predecida
plt.figure(figsize=(2,2))
plt.imshow(preds[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model


# Utilizar el modelo para predecir las imágenes reconstruidas
reconstructed_images = model.predict(noise_test.reshape(-1, 28, 28, 1))

# Calcular el error cuadrático medio (MSE) entre las imágenes reconstruidas y las imágenes originales
mse = np.mean(np.square(X_test.reshape(-1, 28, 28, 1) - reconstructed_images))

# Calcular el porcentaje de error con respecto al original
percentage_error = mse / np.mean(np.square(X_test.reshape(-1, 28, 28, 1)))

print(f"Porcentaje de error con respecto al original: {percentage_error:.2%}")
# Out:
# 313/313 [==============================] - 13s 40ms/step
# Porcentaje de error con respecto al original: 17.94%
