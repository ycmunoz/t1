# %%
#importacion de librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.datasets import  fashion_mnist
# Out:
# 2023-07-24 05:47:33.554670: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import cv2
import numpy as np
from tensorflow.keras.datasets import fashion_mnist

# Cargando el dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalizando las imágenes y convirtiéndolas a 32 bits de punto flotante
X_train, X_test = X_train.astype(np.float32) / 255.0, X_test.astype(np.float32) / 255.0

def add_noise(X):
    result = []
    for img in X:
        # Aplica el filtrado bilateral a la imagen de punto flotante
        noisy = cv2.bilateralFilter(src=img, d=9, sigmaColor=75, sigmaSpace=75)

        result.append(noisy)

    return np.array(result)

# Aplicar el filtrado bilateral a los conjuntos de entrenamiento y prueba
noise_train = add_noise(X_train)
noise_test = add_noise(X_test)

# %%
#aplicando el desenfocado de filtrado bilateral
def add_noise(X):
    res = []
    for pic in X:
        blur = cv2.bilateralFilter(src=pic, d=9, sigmaColor=75, sigmaSpace=75)
        res.append(blur)
    return np.array(res)
noise_train = add_noise(X_train)
noise_test = add_noise(X_test)

# %%
#contruyendo el modelo
from keras import models, layers
model = models.Sequential()
#encode
model.add(layers.Conv2D(64, (2, 2), strides = 1, padding = 'same', input_shape = (28, 28, 1)))
model.add(layers.Conv2D(32, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2D(16, (2, 2), strides = 1, padding = 'same'))
#latent
model.add(layers.Conv2D(8, (2, 2), strides = 1, padding = 'same'))
#decode
model.add(layers.Conv2DTranspose(16, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(32, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(64, (2, 2), strides = 1, padding = 'same'))
model.add(layers.Conv2DTranspose(1, (1, 1), strides = 1, activation = 'sigmoid', padding = 'same'))
# Out:
# 2023-07-22 12:29:35.259967: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-22 12:29:35.376177: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
#entrenando el modelo
model.compile(loss = 'mse', optimizer = 'adam')
model.fit(noise_train.reshape(-1, 28, 28, 1), 
          X_train.reshape(-1, 28, 28, 1), 
          epochs = 100, 
          batch_size = 2000, 
          validation_data = (noise_test.reshape(-1  , 28, 28, 1),X_test.reshape(-1, 28, 28, 1)))

model.save("model-d_bilateral.h5")
# Out:
# Epoch 1/100
# 30/30 [==============================] - 138s 4s/step - loss: 0.0681 - val_loss: 0.0356
# Epoch 2/100
# 30/30 [==============================] - 136s 5s/step - loss: 0.0316 - val_loss: 0.0287
# Epoch 3/100
# 30/30 [==============================] - 149s 5s/step - loss: 0.0275 - val_loss: 0.0265
# Epoch 4/100
# 30/30 [==============================] - 149s 5s/step - loss: 0.0259 - val_loss: 0.0255
# Epoch 5/100
# 30/30 [==============================] - 153s 5s/step - loss: 0.0251 - val_loss: 0.0253
# Epoch 6/100
# 30/30 [==============================] - 163s 5s/step - loss: 0.0248 - val_loss: 0.0244
# Epoch 7/100
# 30/30 [==============================] - 134s 4s/step - loss: 0.0241 - val_loss: 0.0239
# Epoch 8/100
# 30/30 [==============================] - 152s 5s/step - loss: 0.0238 - val_loss: 0.0236
# Epoch 9/100
# 30/30 [==============================] - 134s 4s/step - loss: 0.0235 - val_loss: 0.0234
# Epoch 10/100
# 30/30 [==============================] - 131s 4s/step - loss: 0.0240 - val_loss: 0.0237
# Epoch 11/100
# 30/30 [==============================] - 133s 4s/step - loss: 0.0235 - val_loss: 0.0232
# Epoch 12/100
# 30/30 [==============================] - 142s 5s/step - loss: 0.0231 - val_loss: 0.0230
# Epoch 13/100
# 30/30 [==============================] - 124s 4s/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 14/100
# 30/30 [==============================] - 114s 4s/step - loss: 0.0227 - val_loss: 0.0226
# Epoch 15/100
# 30/30 [==============================] - 111s 4s/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 16/100
# 30/30 [==============================] - 106s 4s/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 17/100
# 30/30 [==============================] - 105s 4s/step - loss: 0.0216 - val_loss: 0.0213
# Epoch 18/100
# 30/30 [==============================] - 107s 4s/step - loss: 0.0214 - val_loss: 0.0212
# Epoch 19/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0212 - val_loss: 0.0211
# Epoch 20/100
# 30/30 [==============================] - 105s 3s/step - loss: 0.0210 - val_loss: 0.0210
# Epoch 21/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0209 - val_loss: 0.0208
# Epoch 22/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 23/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0206 - val_loss: 0.0206
# Epoch 24/100
# 30/30 [==============================] - 105s 4s/step - loss: 0.0203 - val_loss: 0.0201
# Epoch 25/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0200 - val_loss: 0.0198
# Epoch 26/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0197 - val_loss: 0.0196
# Epoch 27/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0195 - val_loss: 0.0194
# Epoch 28/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 29/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0192 - val_loss: 0.0191
# Epoch 30/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0190 - val_loss: 0.0190
# Epoch 31/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0189 - val_loss: 0.0188
# Epoch 32/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0188 - val_loss: 0.0188
# Epoch 33/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0188 - val_loss: 0.0187
# Epoch 34/100
# 30/30 [==============================] - 105s 3s/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 35/100
# 30/30 [==============================] - 105s 4s/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 36/100
# 30/30 [==============================] - 110s 4s/step - loss: 0.0185 - val_loss: 0.0185
# Epoch 37/100
# 30/30 [==============================] - 106s 4s/step - loss: 0.0184 - val_loss: 0.0185
# Epoch 38/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0184 - val_loss: 0.0185
# Epoch 39/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0184 - val_loss: 0.0183
# Epoch 40/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 41/100
# 30/30 [==============================] - 105s 3s/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 42/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0182 - val_loss: 0.0182
# Epoch 43/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0182 - val_loss: 0.0181
# Epoch 44/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0182 - val_loss: 0.0181
# Epoch 45/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 46/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 47/100
# 30/30 [==============================] - 105s 3s/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 48/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 49/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 50/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 51/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 52/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 53/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 54/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 55/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 56/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 57/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 58/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0177 - val_loss: 0.0178
# Epoch 59/100
# 30/30 [==============================] - 105s 4s/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 60/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0179 - val_loss: 0.0177
# Epoch 61/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 62/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 63/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 64/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 65/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0177 - val_loss: 0.0177
# Epoch 66/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0177 - val_loss: 0.0176
# Epoch 67/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 68/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 69/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 70/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 71/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 72/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 73/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0176 - val_loss: 0.0175
# Epoch 74/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 75/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 76/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 77/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 78/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 79/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 80/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 81/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 82/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 83/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 84/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 85/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 86/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 87/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 88/100
# 30/30 [==============================] - 102s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 89/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 90/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 91/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 92/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 93/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 94/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 95/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 96/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 97/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 98/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 99/100
# 30/30 [==============================] - 103s 3s/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 100/100
# 30/30 [==============================] - 104s 3s/step - loss: 0.0176 - val_loss: 0.0175

# %%
#cargando el modelo
model = keras.models.load_model('model-d_bilateral.h5')

#viendo la arquitectura del modelo
model.summary()
# Out:
# 2023-07-24 05:48:10.133324: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 05:48:10.213042: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        8224
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 16)        2064
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 8)         520
#
#  conv2d_transpose (Conv2DTra  (None, 28, 28, 16)       528
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       2080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 64)       8256
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        65
#  ranspose)
#
# =================================================================
# Total params: 22,057
# Trainable params: 22,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
import random
#utility function to pick samples to be tested
def get_samples(arr, n):
    temp = random.sample(range(len(arr)), n)
    result = arr[temp]
    return result, temp
num = 15
org, temp = get_samples(X_test, num)
blur = noise_test[temp]
preds = model.predict(blur.reshape(-1, 28, 28, 1))
preds = preds.reshape(-1, 28, 28)
#plotting results
plt.figure(figsize = (15, 15))
print('Original Images')
for i in range(num):
    plt.subplot(1, num, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(org[i], cmap=plt.cm.binary)
plt.show()

plt.figure(figsize = (15, 15))
print('Blurred Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(blur[i], cmap=plt.cm.binary)
plt.show()
plt.figure(figsize = (15, 15))
print('Predicted Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(preds[i], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 1s 885ms/step
# Original Images
# Blurred Images
# Predicted Images

# %%
#1era imagen  original
plt.figure(figsize=(2,2))
plt.imshow(org[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
#1era imagen desfocada
plt.figure(figsize=(2,2))
plt.imshow(blur[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
#1era imagen predecida
plt.figure(figsize=(2,2))
plt.imshow(preds[0], cmap='binary')
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model


# Utilizar el modelo para predecir las imágenes reconstruidas
reconstructed_images = model.predict(noise_test.reshape(-1, 28, 28, 1))

# Calcular el error cuadrático medio (MSE) entre las imágenes reconstruidas y las imágenes originales
mse = np.mean(np.square(X_test.reshape(-1, 28, 28, 1) - reconstructed_images))

# Calcular el porcentaje de error con respecto al original
percentage_error = mse / np.mean(np.square(X_test.reshape(-1, 28, 28, 1)))

print(f"Porcentaje de error con respecto al original: {percentage_error:.2%}")
# Out:
# 313/313 [==============================] - 14s 44ms/step
# Porcentaje de error con respecto al original: 8.46%
